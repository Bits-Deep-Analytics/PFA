# %%
## Please write your code here
## Only to be submitted by team leader
import pandas as pd
import numpy as np

# %%
url='https://raw.githubusercontent.com/Bits-Deep-Analytics/PFA/main/Iris.csv'
data=pd.read_csv(url)
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['pl_pw']=data['PetalLengthCm']/data['PetalWidthCm']
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    pl_pw
# 0    7.0
# 1    7.0
# 2    6.5
# 3    7.5
# 4    7.0

# %%
data['sl_sw']=data['SepalLengthCm']/data['SepalWidthCm']
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    pl_pw     sl_sw
# 0    7.0  1.457143
# 1    7.0  1.633333
# 2    6.5  1.468750
# 3    7.5  1.483871
# 4    7.0  1.388889

# %%
data['plw_slw']=data['pl_pw']/data['sl_sw']
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    pl_pw     sl_sw   plw_slw
# 0    7.0  1.457143  4.803922
# 1    7.0  1.633333  4.285714
# 2    6.5  1.468750  4.425532
# 3    7.5  1.483871  5.054348
# 4    7.0  1.388889  5.040000

# %%
final_data=data.drop(columns=['Id','SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])
final_data.head()
# Out:
#        Species  pl_pw     sl_sw   plw_slw
# 0  Iris-setosa    7.0  1.457143  4.803922
# 1  Iris-setosa    7.0  1.633333  4.285714
# 2  Iris-setosa    6.5  1.468750  4.425532
# 3  Iris-setosa    7.5  1.483871  5.054348
# 4  Iris-setosa    7.0  1.388889  5.040000

# %%
final_data.to_csv('group_13_pfa_test_task-2.csv',index=False)
print('dataset saved successfully')
# Out:
# dataset saved successfully
