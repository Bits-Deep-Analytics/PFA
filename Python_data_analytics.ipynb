# %% [markdown]
# <a href="https://colab.research.google.com/github/Bits-Deep-Analytics/PFA/blob/main/Python_data_analytics.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open this notebook in Colaboratory"/></a>

# %%
import pandas as pd
students = {'Name': ['Vijay','Raveena','Parul','Paridhi','Pankaj','Sanjay','Aarti','Lokesh','Anukriti','Ankit'], 'Gender': ['M','M','F','F','M','M','F','M','F','M'], 'Marks':[23,64,34,76,45,34,75,34,75,87]}
# print(students)
data = pd.DataFrame(students)
# print(data)
# data.describe()
# print(data.describe())
# print(data.isna())
# display(data)
# data.dtypes
# Out:
#       Name Gender  Marks  Indexes
# 0    Vijay      M     23        3
# 1  Raveena      M     64        1

# %%
# m = data['Marks'].mean()
# data = data.fillna(m)
# data = data.drop("Name", axis = 1)
# data1 = (data['Marks'] == None)
# display(data1)
# data3 = data.sort_values(['Gender','Marks'], ascending = True)
# display(data)
sub = 'a'
data["Indexes"]= data["Name"].str.find(sub)
d1 = data.groupby(['Gender'])
# d1.apply(display)
d2 = data.loc[0:2, :]
print(d2)
# d1 = data.transpose()
# display(d1)

# %%
y = data['Marks']
x = data['Name']
import seaborn as sb
sb.scatterplot(x=x, y=y)
# sb.lineplot(x=x, y=y)
# sb.barplot(x=x, y)
# sb.histplot(x,y)
# Out:
# <Axes: xlabel='Name', ylabel='Marks'>
