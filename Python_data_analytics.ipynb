# %%
import pandas as pd
students = {"Name":["Deepak","Nikhil","Haripriya"], "Marks":[None,76,89], "Gender":["M","M","F"]}
# print(students)
# data = pd.DataFrame(students)
# print(data)
# data.describe()
# print(data.describe())
# print(data.isna().sum())
# display(data)

# data.dtypes
# m = data['Marks'].mean()
# data = data.fillna(m)
# data = data.drop("Name", axis = 1)
# data1 = data[data.Marks > 80]
# display(data1)
# data3 = data.sort_values('Marks', ascending = False)
# display(data3)
# Out:
#    Marks Gender
# 2   89.0      F
# 0   82.5      M
# 1   76.0      M
